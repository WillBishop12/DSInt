# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
#first look at document_tree to get a general idea of the file layout
document_tree.findall('country')
# Out:
# [<Element 'country' at 0x3f3fa20>,
#  <Element 'country' at 0x40a6b38>,
#  <Element 'country' at 0x4067278>,
#  <Element 'country' at 0x40f4048>,
#  <Element 'country' at 0x4102048>,
#  <Element 'country' at 0x4102b00>,
#  <Element 'country' at 0x41112b0>]

# %%
root = document_tree.getroot()

# %%
#see what variable names are
for node in root.getiterator():
    print node.tag, node.attrib, node.text, node.tail
# Out:
# mondial {}
#     None
# country {'memberships': 'org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '28750', 'car_code': 'AL', 'capital': 'cty-Albania-Tirane'}
#
#
# name {} Albania
#
# population {'measured': 'est.', 'year': '1950'} 1214489
#
# population {'measured': 'est.', 'year': '1960'} 1618829
#
# population {'measured': 'est.', 'year': '1970'} 2138966
#
# population {'measured': 'est.', 'year': '1980'} 2734776
#
# population {'measured': 'est.', 'year': '1990'} 3446882
#
# population {'year': '1997'} 3249136
#
# population {'measured': 'est.', 'year': '2000'} 3304948
#
# population {'measured': 'census', 'year': '2001'} 3069275
#
# population {'measured': 'census', 'year': '2011'} 2800138
#
# population_growth {} 0.3
#
# infant_mortality {} 13.19
#
# gdp_total {} 12800
#
# gdp_agri {} 19.5
#
# gdp_ind {} 12
#
# gdp_serv {} 68.5
#
# inflation {} 1.7
#
# unemployment {} 16.9
#
# indep_date {'from': 'Ottoman Empire'} 1912-11-28
#
# government {} parliamentary democracy
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '95'} Albanian
#
# ethnicgroup {'percentage': '3'} Greek
#
# religion {'percentage': '70'} Muslim
#
# religion {'percentage': '10'} Roman Catholic
#
# religion {'percentage': '20'} Christian Orthodox
#
# language {'percentage': '98.8'} Albanian
#
# language {'percentage': '0.5'} Greek
#
# border {'country': 'GR', 'length': '282'} None
#
# border {'country': 'MK', 'length': '151'} None
#
# border {'country': 'MNE', 'length': '172'} None
#
# border {'country': 'KOS', 'length': '112'} None
#
# city {'country': 'AL', 'id': 'cty-Albania-Tirane'}
#
#
# name {} Tirana
#
# name {} Tirane
#
# latitude {} 41.3
#
# longitude {} 19.8
#
# population {'year': '1987'} 192000
#
# population {'measured': 'estimate', 'year': '1990'} 244153
#
# population {'measured': 'census', 'year': '2011'} 418495
#
# city {'country': 'AL', 'id': 'stadt-Shkoder-AL-AL'}
#
#
# name {} Shkodër
#
# latitude {} 42.2
#
# longitude {} 19.2
#
# population {'year': '1987'} 62000
#
# population {'measured': 'census', 'year': '2011'} 77075
#
# located_at {'watertype': 'lake', 'lake': 'lake-Skutarisee'} None
#
# city {'country': 'AL', 'id': 'stadt-Durres-AL-AL'}
#
#
# name {} Durrës
#
# latitude {} 41.3
#
# longitude {} 19.3
#
# population {'year': '1987'} 60000
#
# population {'measured': 'census', 'year': '2011'} 113249
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'country': 'AL', 'id': 'stadt-Vlore-AL-AL'}
#
#
# name {} Vlorë
#
# latitude {} 40.3
#
# longitude {} 19.3
#
# population {'year': '1987'} 56000
#
# population {'measured': 'census', 'year': '2011'} 79513
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'country': 'AL', 'id': 'stadt-Elbasan-AL-AL'}
#
#
# name {} Elbasan
#
# latitude {} 41.1
#
# longitude {} 20.1
#
# population {'year': '1987'} 53000
#
# population {'measured': 'census', 'year': '2011'} 78703
#
# city {'country': 'AL', 'id': 'stadt-Korce-AL-AL'}
#
#
# name {} Korçë
#
# latitude {} 40.4
#
# longitude {} 20.5
#
# population {'year': '1987'} 52000
#
# population {'measured': 'census', 'year': '2011'} 51152
#
# country {'memberships': 'org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC', 'area': '131940', 'car_code': 'GR', 'capital': 'cty-Greece-Athens'}
#
#
# name {} Greece
#
# localname {} Ελληνική Δημοκρατία
#
# population {'measured': 'census', 'year': '1861'} 1096810
#
# population {'measured': 'census', 'year': '1870'} 1457894
#
# population {'measured': 'census', 'year': '1879'} 1679470
#
# population {'measured': 'census', 'year': '1896'} 2433806
#
# population {'measured': 'census', 'year': '1907'} 2631592
#
# population {'measured': 'census', 'year': '1920'} 5016889
#
# population {'measured': 'census', 'year': '1928'} 6204684
#
# population {'measured': 'census', 'year': '1940'} 7344860
#
# population {'measured': 'census', 'year': '1951'} 7632801
#
# population {'measured': 'census', 'year': '1961'} 8388553
#
# population {'measured': 'census', 'year': '1971'} 8768372
#
# population {'measured': 'census', 'year': '1981'} 9739589
#
# population {'measured': 'census', 'year': '1991'} 10217335
#
# population {'measured': 'census', 'year': '2001'} 10934097
#
# population {'measured': 'census', 'year': '2011'} 10816286
#
# population_growth {} 0.01
#
# infant_mortality {} 4.78
#
# gdp_total {} 243300
#
# gdp_agri {} 3.5
#
# gdp_ind {} 16
#
# gdp_serv {} 80.5
#
# inflation {} -0.8
#
# unemployment {} 27.9
#
# indep_date {'from': 'Ottoman Empire'} 1829-01-01
#
# government {} parliamentary republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '93'} Greek
#
# religion {'percentage': '98'} Christian Orthodox
#
# religion {'percentage': '1.3'} Muslim
#
# language {'percentage': '99'} Greek
#
# border {'country': 'AL', 'length': '282'} None
#
# border {'country': 'MK', 'length': '228'} None
#
# border {'country': 'BG', 'length': '494'} None
#
# border {'country': 'TR', 'length': '206'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-2', 'capital': 'cty-Greece-Komotini'}
#
#
# name {} Anatolikis Makedonias kai Thrakis
#
# localname {} Ανατολικής Μακεδονίας και Θράκης
#
# area {} 14157
#
# population {'measured': 'census', 'year': '1991'} 570197
#
# population {'year': '1994'} 574308
#
# population {'measured': 'census', 'year': '2001'} 607162
#
# population {'measured': 'census', 'year': '2011'} 608182
#
# city {'province': 'prov-Greece-2', 'country': 'GR', 'id': 'cty-Greece-Komotini'}
#
#
# name {} Komotini
#
# city {'province': 'prov-Greece-2', 'country': 'GR', 'id': 'cty-Greece-9'}
#
#
# name {} Kavala
#
# population {'year': '1981'} 56705
#
# population {'measured': 'census', 'year': '1991'} 60187
#
# population {'measured': 'census', 'year': '2001'} 63774
#
# population {'measured': 'census', 'year': '2011'} 58790
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-3', 'capital': 'cty-Greece-Athens'}
#
#
# name {} Attikis
#
# localname {} Αττικής
#
# area {} 3808
#
# population {'measured': 'census', 'year': '1991'} 3594817
#
# population {'year': '1994'} 3522769
#
# population {'measured': 'census', 'year': '2001'} 3894573
#
# population {'measured': 'census', 'year': '2011'} 3828434
#
# city {'province': 'prov-Greece-3', 'country': 'GR', 'id': 'cty-Greece-Athens'}
#
#
# name {} Athina
#
# localname {} Αθήνα
#
# latitude {} 38.0
#
# longitude {} 23.75
#
# population {'year': '1981'} 885737
#
# population {'measured': 'census', 'year': '1991'} 816556
#
# population {'measured': 'census', 'year': '2001'} 789166
#
# population {'measured': 'census', 'year': '2011'} 664046
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'province': 'prov-Greece-3', 'country': 'GR', 'id': 'cty-Greece-4'}
#
#
# name {} Peiraias
#
# name {} Piräus
#
# localname {} Πειραιάς
#
# population {'year': '1981'} 196389
#
# population {'measured': 'census', 'year': '1991'} 187399
#
# population {'measured': 'census', 'year': '2001'} 181933
#
# population {'measured': 'census', 'year': '2011'} 163688
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# city {'province': 'prov-Greece-3', 'country': 'GR', 'id': 'cty-Greece-Peristeri'}
#
#
# name {} Peristeri
#
# localname {} Περιστέρι
#
# population {'measured': 'census', 'year': '1991'} 141971
#
# population {'measured': 'census', 'year': '2001'} 146743
#
# population {'measured': 'census', 'year': '2011'} 139981
#
# city {'province': 'prov-Greece-3', 'country': 'GR', 'id': 'cty-Greece-Acharnes'}
#
#
# name {} Acharnes
#
# localname {} Αχαρνές
#
# population {'measured': 'census', 'year': '1991'} 65035
#
# population {'measured': 'census', 'year': '2001'} 82555
#
# population {'measured': 'census', 'year': '2011'} 106943
#
# province {'country': 'GR', 'id': 'prov-Greece-4', 'capital': 'cty-Greece-5'}
#
#
# name {} Dytikis Elladas
#
# localname {} Δυτικής Ελλάδας
#
# area {} 11350
#
# population {'measured': 'census', 'year': '1991'} 695044
#
# population {'year': '1994'} 702027
#
# population {'measured': 'census', 'year': '2001'} 721541
#
# population {'measured': 'census', 'year': '2011'} 679796
#
# city {'province': 'prov-Greece-4', 'country': 'GR', 'id': 'cty-Greece-5'}
#
#
# name {} Patra
#
# name {} Patras
#
# localname {} Πάτρα
#
# population {'year': '1981'} 142163
#
# population {'measured': 'census', 'year': '1991'} 190463
#
# population {'measured': 'census', 'year': '2001'} 210494
#
# population {'measured': 'census', 'year': '2011'} 213984
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-5', 'capital': 'cty-Greece-Kozani'}
#
#
# name {} Dytikis Makedonias
#
# localname {} Δυτικής Μακεδονίας
#
# area {} 9451
#
# population {'measured': 'census', 'year': '1991'} 288495
#
# population {'year': '1994'} 292751
#
# population {'measured': 'census', 'year': '2001'} 294317
#
# population {'measured': 'census', 'year': '2011'} 283689
#
# city {'province': 'prov-Greece-5', 'country': 'GR', 'id': 'cty-Greece-Kozani'}
#
#
# name {} Kozani
#
# province {'country': 'GR', 'id': 'prov-Greece-6', 'capital': 'cty-Greece-Korfu'}
#
#
# name {} Ionion Nison
#
# localname {} Ιονίων Νήσων
#
# area {} 2306
#
# population {'measured': 'census', 'year': '1991'} 189338
#
# population {'year': '1994'} 191003
#
# population {'measured': 'census', 'year': '2001'} 209608
#
# population {'measured': 'census', 'year': '2011'} 207855
#
# city {'province': 'prov-Greece-6', 'country': 'GR', 'id': 'cty-Greece-Korfu'}
#
#
# name {} Kerkyra
#
# name {} Korfu
#
# localname {} Κέρκυρας
#
# population {'measured': 'census', 'year': '1991'} 101236
#
# population {'measured': 'census', 'year': '2001'} 108652
#
# population {'measured': 'census', 'year': '2011'} 102071
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Korfu'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-7', 'capital': 'cty-Greece-Ioannina'}
#
#
# name {} Ipeiroy
#
# localname {} Ηπείρου
#
# area {} 9203
#
# population {'measured': 'census', 'year': '1991'} 327176
#
# population {'measured': 'census', 'year': '2001'} 336392
#
# population {'measured': 'census', 'year': '2011'} 336856
#
# city {'province': 'prov-Greece-7', 'country': 'GR', 'id': 'cty-Greece-Ioannina'}
#
#
# name {} Ioannina
#
# localname {} Ιωαννιτών
#
# population {'measured': 'census', 'year': '1991'} 92425
#
# population {'measured': 'census', 'year': '2001'} 103101
#
# population {'measured': 'census', 'year': '2011'} 112486
#
# province {'country': 'GR', 'id': 'prov-Greece-8', 'capital': 'cty-Greece-Thessaloniki'}
#
#
# name {} Kentrikis Makedonias
#
# localname {} Κεντρικής Μακεδονίας
#
# area {} 18810
#
# population {'measured': 'census', 'year': '1991'} 1706338
#
# population {'year': '1994'} 1729581
#
# population {'measured': 'census', 'year': '2001'} 1874597
#
# population {'measured': 'census', 'year': '2011'} 1880297
#
# city {'province': 'prov-Greece-8', 'country': 'GR', 'id': 'cty-Greece-Thessaloniki'}
#
#
# name {} Thessaloniki
#
# localname {} Θεσσαλονίκη
#
# latitude {} 40.6167
#
# longitude {} 22.95
#
# population {'year': '1981'} 406413
#
# population {'measured': 'census', 'year': '1991'} 424220
#
# population {'measured': 'census', 'year': '2001'} 397156
#
# population {'measured': 'census', 'year': '2011'} 325182
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-9', 'capital': 'cty-Greece-7'}
#
#
# name {} Kritis
#
# localname {} Κρήτης
#
# area {} 8335
#
# population {'measured': 'census', 'year': '1991'} 536633
#
# population {'year': '1994'} 537183
#
# population {'measured': 'census', 'year': '2001'} 594368
#
# population {'measured': 'census', 'year': '2011'} 623065
#
# city {'province': 'prov-Greece-9', 'country': 'GR', 'id': 'cty-Greece-7'}
#
#
# name {} Iraklio
#
# name {} Iraklion
#
# localname {} Ηράκλειο
#
# population {'year': '1981'} 102398
#
# population {'measured': 'census', 'year': '1991'} 146536
#
# population {'measured': 'census', 'year': '2001'} 163115
#
# population {'measured': 'census', 'year': '2011'} 173993
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Crete'} None
#
# city {'province': 'prov-Greece-9', 'country': 'GR', 'id': 'cty-Greece-Chania'}
#
#
# name {} Chania
#
# localname {} Χανίων
#
# population {'measured': 'census', 'year': '1991'} 83712
#
# population {'measured': 'census', 'year': '2001'} 98202
#
# population {'measured': 'census', 'year': '2011'} 108642
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Crete'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-10', 'capital': 'cty-Greece-Ermoupoli'}
#
#
# name {} Notioy Aigaioy
#
# localname {} Νότιου Αιγαίου
#
# area {} 5285
#
# population {'measured': 'census', 'year': '1991'} 255192
#
# population {'year': '1994'} 262522
#
# population {'measured': 'census', 'year': '2001'} 298462
#
# population {'measured': 'census', 'year': '2011'} 309015
#
# city {'province': 'prov-Greece-10', 'country': 'GR', 'id': 'cty-Greece-Ermoupoli'}
#
#
# name {} Ermoupoli
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Syros'} None
#
# city {'province': 'prov-Greece-10', 'country': 'GR', 'id': 'cty-Greece-Rhodes'}
#
#
# name {} Rhodes
#
# name {} Rhodos
#
# localname {} Ρόδου
#
# population {'measured': 'census', 'year': '1991'} 96159
#
# population {'measured': 'census', 'year': '2001'} 115334
#
# population {'measured': 'census', 'year': '2011'} 115490
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Rhodos'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-11', 'capital': 'cty-Greece-Tripoli'}
#
#
# name {} Peloponnisos
#
# localname {} Πελοποννήσου
#
# area {} 15489
#
# population {'measured': 'census', 'year': '1991'} 573958
#
# population {'measured': 'census', 'year': '2001'} 597622
#
# population {'measured': 'census', 'year': '2011'} 577903
#
# city {'province': 'prov-Greece-11', 'country': 'GR', 'id': 'cty-Greece-Tripoli'}
#
#
# name {} Tripoli
#
# province {'country': 'GR', 'id': 'prov-Greece-12', 'capital': 'cty-Greece-Lamia'}
#
#
# name {} Stereas Elladas
#
# localname {} Στερεάς Ελλάδας
#
# area {} 15549
#
# population {'measured': 'census', 'year': '1991'} 548101
#
# population {'measured': 'census', 'year': '2001'} 558144
#
# population {'measured': 'census', 'year': '2011'} 547390
#
# city {'province': 'prov-Greece-12', 'country': 'GR', 'id': 'cty-Greece-Lamia'}
#
#
# name {} Lamia
#
# localname {} Λαμία
#
# population {'measured': 'census', 'year': '2011'} 75315
#
# city {'province': 'prov-Greece-12', 'country': 'GR', 'id': 'cty-Greece-Chalkida'}
#
#
# name {} Chalkida
#
# name {} Chalkis
#
# localname {} Χαλκιδέων
#
# population {'measured': 'census', 'year': '1991'} 85573
#
# population {'measured': 'census', 'year': '2001'} 92809
#
# population {'measured': 'census', 'year': '2011'} 102223
#
# province {'country': 'GR', 'id': 'prov-Greece-13', 'capital': 'cty-Greece-6'}
#
#
# name {} Thessalias
#
# localname {} Θεσσαλίας
#
# area {} 14036
#
# population {'measured': 'census', 'year': '1991'} 729268
#
# population {'year': '1994'} 731030
#
# population {'measured': 'census', 'year': '2001'} 740115
#
# population {'measured': 'census', 'year': '2011'} 732762
#
# city {'province': 'prov-Greece-13', 'country': 'GR', 'id': 'cty-Greece-6'}
#
#
# name {} Larissa
#
# localname {} Λάρισα
#
# population {'year': '1981'} 102426
#
# population {'measured': 'census', 'year': '1991'} 129429
#
# population {'measured': 'census', 'year': '2001'} 145981
#
# population {'measured': 'census', 'year': '2011'} 162591
#
# city {'province': 'prov-Greece-13', 'country': 'GR', 'id': 'cty-Greece-8'}
#
#
# name {} Volos
#
# localname {} Βόλος
#
# population {'year': '1981'} 71378
#
# population {'measured': 'census', 'year': '1991'} 132917
#
# population {'measured': 'census', 'year': '2001'} 142923
#
# population {'measured': 'census', 'year': '2011'} 144449
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-14', 'capital': 'cty-Greece-Mytilini'}
#
#
# name {} Boreioy Aigaioy
#
# localname {} Βορείου Αιγαίου
#
# area {} 3835
#
# population {'measured': 'census', 'year': '1991'} 201363
#
# population {'year': '1994'} 189541
#
# population {'measured': 'census', 'year': '2001'} 205235
#
# population {'measured': 'census', 'year': '2011'} 199231
#
# city {'province': 'prov-Greece-14', 'country': 'GR', 'id': 'cty-Greece-Mytilini'}
#
#
# name {} Mytilini
#
# located_at {'watertype': 'sea', 'sea': 'sea-Mittelmeer'} None
#
# located_on {'island': 'island-Lesbos'} None
#
# province {'country': 'GR', 'id': 'prov-Greece-15', 'capital': 'cty-Greece-Mytilini'}
#
#
# name {} Aghion Oros
#
# localname {} Άγιο Όρος (Αυτοδιοίκητο)
#
# area {} 335
#
# population {'measured': 'census', 'year': '1991'} 1415
#
# population {'measured': 'census', 'year': '2001'} 1961
#
# population {'measured': 'census', 'year': '2011'} 1811
#
# city {'province': 'prov-Greece-15', 'country': 'GR', 'id': 'cty-Greece-Karyes'}
#
#
# name {} Karyes
#
# population {'year': '2014'} 233
#
# country {'memberships': 'org-BIS org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-OIF org-ITU org-ITUC org-MIGA org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '25333', 'car_code': 'MK', 'capital': 'cty-Macedonia-Skopje'}
#
#
# name {} Macedonia
#
# localname {} Република Македониjа
#
# population {'measured': 'census', 'year': '1921'} 808724
#
# population {'measured': 'census', 'year': '1931'} 949958
#
# population {'measured': 'census', 'year': '1948'} 1152986
#
# population {'measured': 'census', 'year': '1953'} 1304514
#
# population {'measured': 'census', 'year': '1961'} 1406003
#
# population {'measured': 'census', 'year': '1971'} 1647308
#
# population {'measured': 'census', 'year': '1981'} 1909136
#
# population {'measured': 'census', 'year': '1991'} 2033964
#
# population {'measured': 'census', 'year': '1994'} 1935034
#
# population {'measured': 'census', 'year': '2002'} 2022547
#
# population {'measured': 'estimate', 'year': '2011'} 2059794
#
# population_growth {} 0.21
#
# infant_mortality {} 7.9
#
# gdp_total {} 10650
#
# gdp_agri {} 10.2
#
# gdp_ind {} 27.5
#
# gdp_serv {} 62.3
#
# inflation {} 2.8
#
# unemployment {} 28.6
#
# indep_date {'from': 'Yugoslavia'} 1991-09-17
#
# government {} parliamentary democracy
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '64.2'} Macedonian
#
# ethnicgroup {'percentage': '25.2'} Albanian
#
# ethnicgroup {'percentage': '3.9'} Turkish
#
# ethnicgroup {'percentage': '2.7'} Gypsy
#
# ethnicgroup {'percentage': '1.8'} Serb
#
# religion {'percentage': '64.7'} Christian Orthodox
#
# religion {'percentage': '33.3'} Muslim
#
# religion {'percentage': '0.2'} Roman Catholic
#
# language {'percentage': '66.5'} Macedonian
#
# language {'percentage': '25.1'} Albanian
#
# language {'percentage': '3.5'} Turkish
#
# language {'percentage': '1.9'} Roma
#
# language {'percentage': '1.2'} Serbian
#
# border {'country': 'AL', 'length': '151'} None
#
# border {'country': 'GR', 'length': '228'} None
#
# border {'country': 'SRB', 'length': '62'} None
#
# border {'country': 'KOS', 'length': '159'} None
#
# border {'country': 'BG', 'length': '148'} None
#
# city {'country': 'MK', 'id': 'cty-Macedonia-Skopje'}
#
#
# name {} Skopje
#
# localname {} Град Скопје
#
# latitude {} 42
#
# longitude {} 21.5
#
# population {'measured': 'census', 'year': '2002'} 506926
#
# population {'measured': 'estimate', 'year': '2011'} 514967
#
# city {'country': 'MK', 'id': 'cty-Macedonia-Kumanovo'}
#
#
# name {} Kumanovo
#
# localname {} Град Куманово
#
# latitude {} 42.1
#
# longitude {} 21.7
#
# population {'measured': 'census', 'year': '2002'} 105484
#
# population {'measured': 'estimate', 'year': '2011'} 107745
#
# country {'memberships': 'org-BIS org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-G-9 org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-NSG org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNMIL org-UNOCI org-MONUSCO org-UNFICYP org-UNTSO org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '77474', 'car_code': 'SRB', 'capital': 'city-Belgrade-SRB-SRB'}
#
#
# name {} Serbia
#
# localname {} Република Србија
#
# population {'measured': 'est.', 'year': '1950'} 6732256
#
# population {'measured': 'est.', 'year': '1960'} 7657958
#
# population {'measured': 'est.', 'year': '1970'} 8236185
#
# population {'measured': 'est.', 'year': '1980'} 9057483
#
# population {'measured': 'est.', 'year': '1990'} 9735429
#
# population {'measured': 'census', 'year': '1991'} 7620531
#
# population {'measured': 'census', 'year': '2002'} 7498001
#
# population {'measured': 'census', 'year': '2011'} 7120666
#
# population_growth {} -0.46
#
# infant_mortality {} 6.16
#
# gdp_total {} 43680
#
# gdp_agri {} 7.9
#
# gdp_ind {} 31.8
#
# gdp_serv {} 60.3
#
# inflation {} 2.2
#
# unemployment {} 20.1
#
# indep_date {'from': 'Yugoslavia'} 1992-04-11
#
# government {} republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '82.9'} Serb
#
# ethnicgroup {'percentage': '0.9'} Montenegrin
#
# ethnicgroup {'percentage': '3.9'} Hungarian
#
# ethnicgroup {'percentage': '1.4'} Roma
#
# ethnicgroup {'percentage': '1.8'} Bosniak
#
# ethnicgroup {'percentage': '1.1'} Croat
#
# religion {'percentage': '85'} Christian Orthodox
#
# religion {'percentage': '3.2'} Muslim
#
# religion {'percentage': '5.5'} Roman Catholic
#
# religion {'percentage': '1.1'} Protestant
#
# language {'percentage': '88.3'} Serbian
#
# language {'percentage': '3.8'} Hungarian
#
# language {'percentage': '1.8'} Bosnian
#
# language {'percentage': '1.1'} Roma
#
# border {'country': 'H', 'length': '151'} None
#
# border {'country': 'RO', 'length': '476'} None
#
# border {'country': 'BG', 'length': '318'} None
#
# border {'country': 'MK', 'length': '62'} None
#
# border {'country': 'HR', 'length': '241'} None
#
# border {'country': 'BIH', 'length': '357'} None
#
# border {'country': 'MNE', 'length': '124'} None
#
# border {'country': 'KOS', 'length': '352'} None
#
# city {'country': 'SRB', 'id': 'city-Belgrade-SRB-SRB'}
#
#
# name {} Beograd
#
# localname {} Београд
#
# latitude {} 44.8
#
# longitude {} 20.4667
#
# population {'year': '1987'} 1407073
#
# population {'measured': 'census', 'year': '2002'} 1576124
#
# population {'measured': 'census', 'year': '2011'} 1639121
#
# located_at {'river': 'river-Donau', 'watertype': 'river'} None
#
# located_at {'river': 'river-Save', 'watertype': 'river'} None
#
# city {'country': 'SRB', 'id': 'city-NoviSad-SRB-SRB'}
#
#
# name {} Novi Sad
#
# localname {} Нови Сад
#
# population {'measured': 'census', 'year': '2002'} 299294
#
# population {'measured': 'census', 'year': '2011'} 335701
#
# located_at {'river': 'river-Donau', 'watertype': 'river'} None
#
# city {'country': 'SRB', 'id': 'city-Nis-SRB-SRB'}
#
#
# name {} Niš
#
# localname {} Ниш
#
# population {'measured': 'census', 'year': '2002'} 250518
#
# population {'measured': 'census', 'year': '2011'} 257867
#
# located_at {'river': 'river-SouthernMorava', 'watertype': 'river'} None
#
# country {'memberships': 'org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-OSCE org-OPCW org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNMIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '14026', 'car_code': 'MNE', 'capital': 'city-Podgorica-MNE-MNE'}
#
#
# name {} Montenegro
#
# localname {} Црна Гора
#
# population {'measured': 'census', 'year': '1921'} 311341
#
# population {'measured': 'census', 'year': '1931'} 360044
#
# population {'measured': 'census', 'year': '1948'} 377189
#
# population {'measured': 'census', 'year': '1953'} 419873
#
# population {'measured': 'census', 'year': '1961'} 471894
#
# population {'measured': 'census', 'year': '1971'} 529604
#
# population {'measured': 'census', 'year': '1981'} 584310
#
# population {'measured': 'census', 'year': '1991'} 615035
#
# population {'measured': 'census', 'year': '2003'} 620145
#
# population {'measured': 'census', 'year': '2011'} 620029
#
# population_growth {} -0.49
#
# gdp_total {} 4518
#
# gdp_agri {} 0.8
#
# gdp_ind {} 11.3
#
# gdp_serv {} 87.9
#
# inflation {} 4
#
# unemployment {} 19.1
#
# indep_date {'from': 'SRB'} 2006-06-03
#
# government {} republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '43'} Montenegrin
#
# ethnicgroup {'percentage': '32'} Serb
#
# ethnicgroup {'percentage': '8'} Bosniak
#
# ethnicgroup {'percentage': '5'} Albanian
#
# religion {'percentage': '74.2'} Christian Orthodox
#
# religion {'percentage': '17.7'} Muslim
#
# religion {'percentage': '3.5'} Roman Catholic
#
# language {'percentage': '63.6'} Serbian
#
# language {'percentage': '22'} Montenegrin
#
# language {'percentage': '5.5'} Bosnian
#
# language {'percentage': '5.3'} Albanian
#
# border {'country': 'HR', 'length': '25'} None
#
# border {'country': 'SRB', 'length': '124'} None
#
# border {'country': 'BIH', 'length': '249'} None
#
# border {'country': 'AL', 'length': '172'} None
#
# border {'country': 'KOS', 'length': '79'} None
#
# city {'country': 'MNE', 'id': 'city-Podgorica-MNE-MNE'}
#
#
# name {} Podgorica
#
# latitude {} 42.26
#
# longitude {} 19.16
#
# population {'measured': 'census', 'year': '2003'} 136473
#
# population {'measured': 'census', 'year': '2011'} 150977
#
# located_at {'river': 'river-Moraca', 'watertype': 'river'} None
#
# country {'memberships': 'org-CD org-EBRD org-IBRD org-IDA org-IFC org-IMF org-ITUC', 'area': '10887', 'car_code': 'KOS', 'capital': 'city-Pristina-KOS-KOS'}
#
#
# name {} Kosovo
#
# localname {} Republika e Kosovës
#
# population {'measured': 'census', 'year': '1981'} 1584440
#
# population {'measured': 'census', 'year': '1991'} 1956196
#
# population {'measured': 'census', 'year': '2011'} 1733872
#
# gdp_total {} 7150
#
# gdp_agri {} 12.9
#
# gdp_ind {} 22.6
#
# gdp_serv {} 64.5
#
# inflation {} 1.8
#
# unemployment {} 30.9
#
# indep_date {'from': 'SRB'} 2008-02-17
#
# government {} republic
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '92'} Albanian
#
# ethnicgroup {'percentage': '5'} Serbian
#
# religion {'percentage': '90'} Muslim
#
# language {'percentage': '92'} Albanian
#
# language {'percentage': '5'} Serbian
#
# border {'country': 'MNE', 'length': '79'} None
#
# border {'country': 'SRB', 'length': '352'} None
#
# border {'country': 'MK', 'length': '159'} None
#
# border {'country': 'AL', 'length': '112'} None
#
# city {'country': 'KOS', 'id': 'city-Pristina-KOS-KOS'}
#
#
# name {} Prishtine
#
# name {} Pristina
#
# latitude {} 42.40
#
# longitude {} 21.10
#
# population {'measured': 'census', 'year': '1981'} 148090
#
# population {'measured': 'census', 'year': '1991'} 199654
#
# population {'measured': 'census', 'year': '2011'} 198214
#
# country {'memberships': 'org-CE org-FAO org-IPU org-ICC org-ICAO org-ICCt org-Interpol org-IFRCS org-IOC org-OIF org-ITU org-OSCE org-OPCW org-UN org-UNCTAD org-UNESCO org-WCO org-WHO org-WIPO org-UNWTO org-WTO', 'area': '450', 'car_code': 'AND', 'capital': 'cty-Andorra-Andorra-la-Vella'}
#
#
#
# name {} Andorra
#
# localname {} Principat d’Andorra
#
# population {'measured': 'est.', 'year': '1950'} 6197
#
# population {'measured': 'est.', 'year': '1960'} 13414
#
# population {'measured': 'est.', 'year': '1970'} 24279
#
# population {'measured': 'est.', 'year': '1980'} 36063
#
# population {'measured': 'census', 'year': '1989'} 46166
#
# population {'measured': 'admin.', 'year': '2001'} 66334
#
# population {'measured': 'admin.', 'year': '2006'} 81222
#
# population {'measured': 'admin.', 'year': '2011'} 78115
#
# population_growth {} 0.17
#
# infant_mortality {} 3.69
#
# gdp_total {} 4800
#
# gdp_agri {} 14
#
# gdp_ind {} 79
#
# gdp_serv {} 6
#
# inflation {} 1.1
#
# unemployment {} 4
#
# indep_date {} 1278-09-08
#
# government {} parliamentary democracy that retains as its chiefs of state a co-principality
#
# encompassed {'percentage': '100', 'continent': 'europe'} None
#
# ethnicgroup {'percentage': '43'} Spanish
#
# ethnicgroup {'percentage': '33'} Andorran
#
# ethnicgroup {'percentage': '11'} Portuguese
#
# ethnicgroup {'percentage': '2'} French
#
# ethnicgroup {'percentage': '5'} African
#
# religion {'percentage': '95'} Roman Catholic
#
# language {'percentage': '44'} Catalan
#
# language {'percentage': '33'} Spanish
#
# language {'percentage': '2'} Galician
#
# language {'percentage': '11'} Portuguese
#
# language {'percentage': '7'} French
#
# border {'country': 'F', 'length': '60'} None
#
# border {'country': 'E', 'length': '65'} None
#
# city {'country': 'AND', 'id': 'cty-Andorra-Andorra-la-Vella'}
#
#
# name {} Andorra la Vella
#
# latitude {} 42.3
#
# longitude {} 1.3
#
# population {'year': '1987'} 15600
#
# population {'measured': 'admin.', 'year': '2001'} 20787
#
# population {'measured': 'admin.', 'year': '2011'} 22256

# %%
import pandas as pd

# %%
#find infant mortality rates in small file
def get_inf_mort(xml):
    InfMortList = []
    for country in xml.findall('country'):
        name = country.find('name').text
        try:
            inf_mort = float(country.find('infant_mortality').text)
        except AttributeError:
            inf_mort = None
        InfMortList.append([name, inf_mort])
    
    #create data frame
    InfMortDF = pd.DataFrame(InfMortList, columns=['Country', 'Infant Mortality'])
    InfMortDF.sort_values("Infant Mortality", inplace=True)
    return InfMortDF.head(10)
        
get_inf_mort(document_tree)
# Out:
#       Country  Infant Mortality
# 6     Andorra              3.69
# 1      Greece              4.78
# 3      Serbia              6.16
# 2   Macedonia              7.90
# 0     Albania             13.19
# 4  Montenegro               NaN
# 5      Kosovo               NaN

# %%
#now find bottom 10 infant mortality rates in large file
get_inf_mort(document)
# Out:
#             Country  Infant Mortality
# 38           Monaco              1.81
# 98            Japan              2.13
# 117         Bermuda              2.48
# 36           Norway              2.48
# 106       Singapore              2.53
# 37           Sweden              2.60
# 10   Czech Republic              2.63
# 78        Hong Kong              2.73
# 79            Macao              3.13
# 44          Iceland              3.15

# %%
#top 10 cities with the largest population - latest estimate
def get_cities(xml):
    CityList = []
    ec = 0 #error counter
    for country in xml.findall('country'):
        for city in country.findall('city'):
            names = city.iterfind('name')
            name1 = next(names).text
            
            #get an alternative name if one exists
            try: name2 = next(names).text
            except StopIteration: name2 = ""
            
            #get population value
            try:
                """Iterate over all population elements.  For each one, convert the 'year' attribute
                into an integer.  Pick the population value corresponding to the maximum converted year
                value, and convert it to a float."""
                pop = float(max(city.iterfind('population'), key=lambda p: int(p.attrib['year'])).text)
            except ValueError: #no population values so arg of "max" function is empty iterator
                pop = None
                ec += 1
            CityList.append([name1, name2, pop])
    
    CityDF = pd.DataFrame(CityList, columns=['City Name', 'Alt Name', 'Population'])
    CityDF.sort_values('Population', inplace=True, ascending=False)
    print CityDF.shape, ec
    return CityDF.head(10)

get_cities(document_tree)
# Out:
# (14, 3) 0
#     City Name  Alt Name  Population
# 8     Beograd               1639121
# 6      Skopje                514967
# 0      Tirana    Tirane      418495
# 9    Novi Sad                335701
# 10        Niš                257867
# 12  Prishtine  Pristina      198214
# 11  Podgorica                150977
# 2      Durrës                113249
# 7    Kumanovo                107745
# 3       Vlorë                 79513

# %%
#now get top 10 cities in big document
get_cities(document)
# Out:
# (430, 3) 36
#            City Name    Alt Name  Population
# 176            Seoul                 9708483
# 164       Al Qahirah       Cairo     8471859
# 80           Bangkok                 7506700
# 128        Hong Kong                 7055071
# 92       Ho Chi Minh      Saigon     5968384
# 212        Singapore                 5076700
# 163  Al Iskandariyah  Alexandria     4123869
# 216       New Taipei                 3939305
# 177            Busan       Pusan     3403135
# 107        Pyongyang                 3255288

# %%
#find top 10 ethnic groups by population across all countries
def get_ethnic(xml):
    EthnicList = []
    ec = 0 #error counter
    for country in xml.findall('country'):
        cname = country.find('name')
        
        #get most recent country population
        try:
            """Iterate over all population elements.  For each one, convert the 'year' attribute
            into an integer.  Pick the population value corresponding to the maximum converted year
            value, and convert it to a float."""
            cpop = float(max(country.iterfind('population'), key=lambda p: int(p.attrib['year'])).text)
            
            #calculate population of each group in the country
            for ethnic in country.findall('ethnicgroup'):
                ename = ethnic.text
                epct = 0.01 * float(ethnic.attrib['percentage'])
                epop = int(epct * cpop) #round to nearest integer
                EthnicList.append([cname, ename, epop])        
        
        except ValueError: #no population values so arg of "max" function is empty iterator
            ec += 1        
    
    #put each country and ethnic group in a data frame
    EthnicDF = pd.DataFrame(EthnicList, columns=['Country', 'Ethnic Group', 'Population'])
    print EthnicDF.shape, ec
    
    #sum by ethnic group
    return EthnicDF.groupby('Ethnic Group').sum().sort_values('Population', ascending=False).head(10)

#test with small doc
get_ethnic(document_tree)
# Out:
# (25, 3) 0
#               Population
# Ethnic Group
# Greek           10143149
# Serb             6138517
# Albanian         4805362
# Macedonian       1322387
# Montenegrin       330697
# Hungarian         277705
# Bosniak           177773
# Roma               99689
# Serbian            86693
# Turkish            80331

# %%
#now find top 10 ethnic groups in big doc
get_ethnic(document)
# Out:
# (628, 3) 0
#               Population
# Ethnic Group
# Han Chinese   1245058800
# Indo-Aryan     871815583
# European       494872201
# African        318325104
# Dravidian      302713744
# Mestizo        157734349
# Bengali        146776916
# Russian        131856989
# Japanese       126534212
# Malay          121993548

# %%
"""Comment: ethnic groups don't seem to be entirely consistent here.  For instance one might expect 
'Russian' to be a subset of 'European'.  Ideally we would have different levels of ethnic groups identified
in the XML file, but this doesn't appear possible with the data we have, so in a real 
data science exercise, we would explore the smaller groups to see which are subsets of the larger ones
to avoid reporting misleading numbers."""
# Out:
# "Comment: ethnic groups don't seem to be entirely consistent here.  For instance one might expect \n'Russian' to be a subset of 'European'.  Ideally we would have different levels of ethnic groups identified\nin the XML file, but this doesn't appear possible with the data we have, so in a real \ndata science exercise, we would explore the smaller groups to see which are subsets of the larger ones\nto avoid reporting misleading numbers."

# %%
#find longest river, largest lake, and highest-elevation airport
#in small file, there are no examples of river lengths, lake sizes, or airport elevations
#need to look at large file to see format...

#create dictionary of country abbreviations
AbbrDict = {}
for country in document.findall('country'):
    AbbrDict[country.attrib['car_code']] = country.find('name').text

def highest_airport(xml):
    AirportList = []
    ec = 0 #error counter
    for airport in xml.findall('airport'):
        try:
            arpt = {
                    'name': airport.find('name').text,
                    'country': AbbrDict[airport.attrib['country']],
                    #'latitude': float(airport.find('latitude').text),
                    #'longitude': float(airport.find('longitude').text),
                    'elevation': int(airport.find('elevation').text),
                    #'GMToffset': float(airport.find('gmtOffset').text)
                }
        except TypeError:
            ec += 1
        except AttributeError:
            ec += 1
        AirportList.append(arpt)
        
    print len(AirportList), ec
    return max(AirportList, key=lambda a: a['elevation'])

highest_airport(document)
# Out:
# 1315 26
# {'country': 'Bolivia', 'elevation': 4063, 'name': 'El Alto Intl'}

# %%
def largest_lake(xml):
    LakeList = []
    ec = 0 #error counter
    for lake in xml.findall('lake'):
        countries = []
        for loc in lake.findall('located'): #lakes can be in multiple countries
            c = AbbrDict[loc.attrib['country']]
            countries.append(c)
        try:
            lk = {
                    'name': lake.find('name').text,
                    'country': countries,
                    'area': float(lake.find('area').text)
                    }
        except TypeError:
            ec += 1
        except AttributeError:
            ec += 1
        LakeList.append(lk)
            
    print len(LakeList), ec
    return max(LakeList, key=lambda x: x['area'])

largest_lake(document)
# Out:
# 141 2
# {'area': 386400.0,
#  'country': ['Russia', 'Kazakhstan', 'Iran', 'Turkmenistan'],
#  'name': 'Caspian Sea'}

# %%
def longest_river(xml):
    RiverList = []
    ec = 0 #error counter
    for river in xml.findall('river'):
        countries = []
        for loc in river.findall('located'): #lakes can be in multiple countries
            c = AbbrDict[loc.attrib['country']]
            countries.append(c)
        try:
            riv = {
                    'name': river.find('name').text,
                    'country': countries,
                    'length': float(river.find('length').text)
                    }
        except TypeError:
            ec += 1
        except AttributeError:
            ec += 1
        RiverList.append(riv)
            
    print len(RiverList), ec
    return max(RiverList, key=lambda x: x['length'])

longest_river(document)
# Out:
# 238 5
# {'country': ['Colombia', 'Brazil', 'Peru'],
#  'length': 6448.0,
#  'name': 'Amazonas'}

# %%
#since river and lake functions are basically identical, we should be able to combine them
def water_size(xml, water_type, water_metric):
    WaterList = []
    ec = 0 #error counter
    for water in xml.findall(water_type):
        countries = []
        for loc in water.findall('located'): #lakes can be in multiple countries
            c = AbbrDict[loc.attrib['country']]
            countries.append(c)
        try:
            H2O = {
                    'name': water.find('name').text,
                    'country': countries,
                    water_metric: float(water.find(water_metric).text)
                    }
        except TypeError:
            ec += 1
        except AttributeError:
            ec += 1
        WaterList.append(H2O)
            
    print len(WaterList), ec
    return max(WaterList, key=lambda x: x[water_metric])

water_size(document, water_type='river', water_metric='length')
# Out:
# 238 5
# {'country': ['Colombia', 'Brazil', 'Peru'],
#  'length': 6448.0,
#  'name': 'Amazonas'}

# %%
water_size(document, water_type='lake', water_metric='area')
# Out:
# 141 2
# {'area': 386400.0,
#  'country': ['Russia', 'Kazakhstan', 'Iran', 'Turkmenistan'],
#  'name': 'Caspian Sea'}
